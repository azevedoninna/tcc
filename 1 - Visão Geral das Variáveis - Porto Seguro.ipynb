# %% [markdown]
# # Biblioteca

# %%
import pandas as pd
import sklearn
import numpy as np
import statsmodels 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(12,7)})
sns.set_style("whitegrid")
sns.set_palette("husl")

# %% [markdown]
# # Dados

# %%
dados = pd.read_csv("porto_seguro.csv")

# %%
dados.describe()
# Out:
#                  id         target      ps_ind_01  ps_ind_02_cat  \
# count  5.952120e+05  595212.000000  595212.000000  595212.000000
# mean   7.438036e+05       0.036448       1.900378       1.358943
# std    4.293678e+05       0.187401       1.983789       0.664594
# min    7.000000e+00       0.000000       0.000000      -1.000000
# 25%    3.719915e+05       0.000000       0.000000       1.000000
# 50%    7.435475e+05       0.000000       1.000000       1.000000
# 75%    1.115549e+06       0.000000       3.000000       2.000000
# max    1.488027e+06       1.000000       7.000000       4.000000
#
#            ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  ps_ind_06_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        4.423318       0.416794       0.405188       0.393742
# std         2.699902       0.493311       1.350642       0.488579
# min         0.000000      -1.000000      -1.000000       0.000000
# 25%         2.000000       0.000000       0.000000       0.000000
# 50%         4.000000       0.000000       0.000000       0.000000
# 75%         6.000000       1.000000       0.000000       1.000000
# max        11.000000       1.000000       6.000000       1.000000
#
#        ps_ind_07_bin  ps_ind_08_bin       ...           ps_calc_11  \
# count  595212.000000  595212.000000       ...        595212.000000
# mean        0.257033       0.163921       ...             5.441382
# std         0.436998       0.370205       ...             2.332871
# min         0.000000       0.000000       ...             0.000000
# 25%         0.000000       0.000000       ...             4.000000
# 50%         0.000000       0.000000       ...             5.000000
# 75%         1.000000       0.000000       ...             7.000000
# max         1.000000       1.000000       ...            19.000000
#
#           ps_calc_12     ps_calc_13     ps_calc_14  ps_calc_15_bin  \
# count  595212.000000  595212.000000  595212.000000   595212.000000
# mean        1.441918       2.872288       7.539026        0.122427
# std         1.202963       1.694887       2.746652        0.327779
# min         0.000000       0.000000       0.000000        0.000000
# 25%         1.000000       2.000000       6.000000        0.000000
# 50%         1.000000       3.000000       7.000000        0.000000
# 75%         2.000000       4.000000       9.000000        0.000000
# max        10.000000      13.000000      23.000000        1.000000
#
#        ps_calc_16_bin  ps_calc_17_bin  ps_calc_18_bin  ps_calc_19_bin  \
# count   595212.000000   595212.000000   595212.000000   595212.000000
# mean         0.627840        0.554182        0.287182        0.349024
# std          0.483381        0.497056        0.452447        0.476662
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          1.000000        1.000000        0.000000        0.000000
# 75%          1.000000        1.000000        1.000000        1.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#        ps_calc_20_bin
# count   595212.000000
# mean         0.153318
# std          0.360295
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
#
# [8 rows x 59 columns]

# %%
dados.groupby("target").id.nunique().reset_index()
# Out:
#    target      id
# 0       0  573518
# 1       1   21694

# %% [markdown]
# # Variáveis

# %%
var = "ps_ind_01"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_01')

# %%
var = "ps_ind_02_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_02_cat')

# %%
var = "ps_ind_03"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_03')

# %%
var = "ps_ind_04_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_04_cat')

# %%
var = "ps_ind_05_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_05_cat')

# %%
var = "ps_ind_06_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_06_bin')

# %%
var = "ps_ind_07_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_07_bin')

# %%
var = "ps_ind_08_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_08_bin')

# %%
var = "ps_ind_09_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_09_bin')

# %%
var = "ps_ind_10_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_10_bin')

# %%
var = "ps_ind_11_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_11_bin')

# %%
var = "ps_ind_12_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_12_bin')

# %%
var = "ps_ind_13_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_13_bin')

# %%
var = "ps_ind_14"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_14')

# %%
var = "ps_ind_15"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_15')

# %%
var = "ps_ind_16_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_16_bin')

# %%
var = "ps_ind_17_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_17_bin')

# %%
var = "ps_ind_18_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_ind_18_bin')

# %%
var = "ps_reg_01"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_reg_01')

# %%
var = "ps_reg_02"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_reg_02')

# %%
var = "ps_car_01_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_01_cat')

# %%
var = "ps_car_02_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_02_cat')

# %%
var = "ps_car_03_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_03_cat')

# %%
var = "ps_car_04_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_04_cat')

# %%
var = "ps_car_02_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_02_cat')

# %%
var = "ps_car_05_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_05_cat')

# %%
var = "ps_car_06_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_06_cat')

# %%
var = "ps_car_07_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_07_cat')

# %%
var = "ps_car_08_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_08_cat')

# %%
var = "ps_car_09_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_09_cat')

# %%
var = "ps_car_10_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_10_cat')

# %%
var = "ps_car_10_cat"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_10_cat')

# %%
var = "ps_car_11"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_11')

# %%
var = "ps_car_15"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_car_15')

# %%
var = "ps_calc_01"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_01')

# %%
var = "ps_calc_02"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_02')

# %%
var = "ps_calc_03"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_03')

# %%
var = "ps_calc_04"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_04')

# %%
var = "ps_calc_05"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_05')

# %%
var = "ps_calc_06"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_06')

# %%
var = "ps_calc_07"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_07')

# %%
var = "ps_calc_08"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_08')

# %%
var = "ps_calc_09"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_09')

# %%
var = "ps_calc_10"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_10')

# %%
var = "ps_calc_11"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_11')

# %%
var = "ps_calc_12"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_12')

# %%
var = "ps_calc_13"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_13')

# %%
var = "ps_calc_14"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_14')

# %%
var = "ps_calc_15_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_15_bin')

# %%
var = "ps_calc_16_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_16_bin')

# %%
var = "ps_calc_17_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_17_bin')

# %%
var = "ps_calc_18_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_18_bin')

# %%
var = "ps_calc_19_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_19_bin')

# %%
var = "ps_calc_20_bin"

ax = sns.barplot(x=var, y="target", data=dados, color="lightgrey")
ax.set_title("Percentagem de sinistros por "+ var)
# Out:
# Text(0.5,1,'Percentagem de sinistros por ps_calc_20_bin')

# %% [markdown]
# # Outras Variáveis

# %% [markdown]
# ### ps_reg_03

# %%
var = "ps_reg_03"

dados[var].hist(bins=20, color="lightgrey").set_title("Histograma de "+ var)
# Out:
# Text(0.5,1,'Histograma de ps_reg_03')

# %%
var = "ps_reg_03"

sns.boxplot(x="target", y=var,  data=dados, color="lightgrey").set_title("Boxplot de "+ var)
# Out:
# Text(0.5,1,'Boxplot de ps_reg_03')

# %% [markdown]
# ### ps_car_11_cat

# %%
var = "ps_car_11_cat"

dados[var].hist(bins=20, color="lightgrey").set_title("Histograma de "+ var)
# Out:
# Text(0.5,1,'Histograma de ps_car_11_cat')

# %%
var = "ps_car_11_cat"

sns.boxplot(x="target", y=var,  data=dados, color="lightgrey").set_title("Boxplot de "+ var)
# Out:
# Text(0.5,1,'Boxplot de ps_car_11_cat')

# %% [markdown]
# ### ps_car_12

# %%
var = "ps_car_12"

dados[var].hist(color="lightgrey").set_title("Histograma de "+ var)
# Out:
# Text(0.5,1,'Histograma de ps_car_12')

# %%
var = "ps_car_12"

sns.boxplot(x="target", y=var,  data=dados, color="lightgrey").set_title("Boxplot de "+ var)
# Out:
# Text(0.5,1,'Boxplot de ps_car_12')

# %% [markdown]
# ### ps_car_13

# %%
var = "ps_car_13"

dados[var].hist(color="lightgrey").set_title("Histograma de "+ var)
# Out:
# Text(0.5,1,'Histograma de ps_car_13')

# %%
var = "ps_car_13"

sns.boxplot(x="target", y=var,  data=dados, color="lightgrey").set_title("Boxplot de "+ var)
# Out:
# Text(0.5,1,'Boxplot de ps_car_13')

# %% [markdown]
# ### ps_car_14

# %%
var = "ps_car_14"

dados[var].hist(color="lightgrey").set_title("Histograma de "+ var)
# Out:
# Text(0.5,1,'Histograma de ps_car_14')

# %%
var = "ps_car_14"

sns.boxplot(x="target", y=var,  data=dados, color="lightgrey").set_title("Boxplot de "+ var)
# Out:
# Text(0.5,1,'Boxplot de ps_car_14')

# %% [markdown]
# # Correlograma

# %%
sns.set(rc={'figure.figsize':(30, 20)})

corr = dados.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
corr = dados.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col0 {
#             background-color:  #b40426;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col1 {
#             background-color:  #445acc;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col2 {
#             background-color:  #81a4fb;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col3 {
#             background-color:  #5d7ce6;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col4 {
#             background-color:  #5572df;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col5 {
#             background-color:  #85a8fc;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col6 {
#             background-color:  #445acc;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col7 {
#             background-color:  #a6c4fe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col8 {
#             background-color:  #a6c4fe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col9 {
#             background-color:  #92b4fe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col10 {
#             background-color:  #96b7ff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col11 {
#             background-color:  #4055c8;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col12 {
#             background-color:  #4b64d5;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col13 {
#             background-color:  #5a78e4;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col14 {
#             background-color:  #455cce;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col15 {
#             background-color:  #5b7ae5;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col16 {
#             background-color:  #a2c1ff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col17 {
#             background-color:  #b7cff9;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col18 {
#             background-color:  #adc9fd;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col19 {
#             background-color:  #b7cff9;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col20 {
#             background-color:  #5f7fe8;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col21 {
#             background-color:  #7295f4;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col22 {
#             background-color:  #5f7fe8;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col23 {
#             background-color:  #6384eb;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col24 {
#             background-color:  #a7c5fe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col25 {
#             background-color:  #7b9ff9;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col26 {
#             background-color:  #81a4fb;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col27 {
#             background-color:  #8caffe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col28 {
#             background-color:  #7b9ff9;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col29 {
#             background-color:  #7597f6;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col30 {
#             background-color:  #94b6ff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col31 {
#             background-color:  #8caffe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col32 {
#             background-color:  #455cce;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col33 {
#             background-color:  #516ddb;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col34 {
#             background-color:  #5470de;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col35 {
#             background-color:  #a5c3fe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col36 {
#             background-color:  #a7c5fe;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col37 {
#             background-color:  #6687ed;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col38 {
#             background-color:  #94b6ff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col39 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col40 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col41 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col42 {
#             background-color:  #3c4ec2;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col43 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col44 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col45 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col46 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col47 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col48 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col49 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col50 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col51 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col52 {
#             background-color:  #3c4ec2;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col53 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col54 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col55 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col56 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col57 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row0_col58 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col1 {
#             background-color:  #b40426;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col2 {
#             background-color:  #86a9fc;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col3 {
#             background-color:  #5e7de7;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col4 {
#             background-color:  #5875e1;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col5 {
#             background-color:  #88abfd;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col6 {
#             background-color:  #4e68d8;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col7 {
#             background-color:  #9ebeff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col8 {
#             background-color:  #aec9fc;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col9 {
#             background-color:  #94b6ff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col10 {
#             background-color:  #94b6ff;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col11 {
#             background-color:  #4257c9;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col12 {
#             background-color:  #4c66d6;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col13 {
#             background-color:  #5d7ce6;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col14 {
#             background-color:  #465ecf;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col15 {
#             background-color:  #5e7de7;
#         }    #T_8ec6f808_5edd_11e9_ad7d_4a00083ce000row1_col16 {
#             background-color:  #9dbdff;
#         }    #T_8ec6f80
